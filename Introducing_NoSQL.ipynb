# %% [markdown]
# <a href="https://colab.research.google.com/github/ssanchezgoe/python_db/blob/master/Introducing_NoSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introducción a NoSQL**
#
# Objetivos de aprendizaje
#
# - Definición del término NoSQL y las tecnologías a las que hace referencia.
# - Descripción de la historia de NoSQL bajo la perspectiva de las bases de datos.
# - Explicación del concepto y características de las bases de datos NoSQL.
# - Lista de los beneficios primarios para adoptar una base de datos NoSQL.

# %% [markdown]
# ##**En qué consite NoSQL**
#
# El término NoSQL fue introducido en un evento para discutir todas las bases de datos open-sources que estaban apareciendo en escena, y el nombre de NoSQL se le acuño desde entonces.
#
# Por desgracia, el término NoSQL hace referencia a lo que no significa de forma literal. Se refiere más bien, a una familia de bases de datos que varian apliamente en estilo y tecnología, pero todas comparte en común que no son de naturaleza relacional, lo que significa que no son un RDBMS (Relational Database Managment System) estandar de filas y columnas. En este sentido, un nombre que mejor describiría a este tipo de bases de datos es que son **no relacionales**.
#
#
# NoSQL $\rightarrow$ "Not Only SQL" (DB mo relacionales)
#
# Las bases de datos NoSQL proporcionan nuevas formas de guardar y consultar datos que aborda una serie de problemas para las aplicaciones modernas. Lo más importante es que la mayoria de bases de datos NoSQL están orientadas a manipular una variedad diferente de problemas de escala que han surgido asociados al tratamiento de grandes datos (big data). Con la *escala* nos referimos tanto al tamaño como la manipulación de varios usuarios en los datos.

# %% [markdown]
# ##**Breve historia de las bases de datos**
#
# Dentro del desarrollo de software, las bases de datos surgen de la neesidad de guardar datos relacionados con una aplicación. Hace 10 años o más, los desarrolladores escogía entre una serie de bases de datos relacionales como:
#
# - Oracle
# - MySQL
# - SQL Server
# - DB2
#
# Posteriormente, entre los 90 y principios del 2000, se da el boom de *dotcom*, por lo que las aplicaciones de internet y las compañias pasan de servir un puñado de empleados en las empresas a millones de usuarios en el internet público. Para estas aplicaciones, la **disponibilidad** y el **rendimiento** fueron primordiales y estos nuevos problemas de escala llevaron a un impulso para crear nuevas tecnologías escalables para dichos datos. Algunas de las tecnologías que aparecen en ese entonces son:
#
# - MapReduce de Google, para el procesamiento de grandes datos en sistemas distribuidos.
# - Dynamo de Amazon, para la distribución de datos y gestión de carga de trabajos en un cluster de un estilo de arquitectura quorum.
#
# A finales del 2000, surgen varias bases de datos omo
#
# - Apache CouchDB
# - Cassandra
# - Hbases
# - Mongo
# - Riak
#
# las cuales se vuelven particularmente útilies para el uso de aplicaciones que requieren datos a gran escala, y que son más faciles de manejar que las bases de datos relacionales.
#
# En los últimos 5 años, varias bases de datos NoSQL han aprovechado un modelo de servicio completamente administrado, también llamado base de datos como servicio, para reducir la administración y el mantenimiento del usuario final y permitir a los desarrolladores centrarse en crear aplicaciones con estas bases de datos modernas.
#
# Una imagen que ilustra una línea de tiempo que define las diferentes bases de datos es la siguiente:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Tipos de bases de datos NoSQL:**
#
# Se han llevado a cabo varias iniciativas para intentar categorizar las bases de datos NoSQL. En el mercado, se ha logrado un consenso general, definiéndose cuatro categorías para las bases de datos NoSQL:
#
# - Key-Value: búsquedas rápidas
# - Document: para el alamacenamiento de información intuitiva *de-normalized*.
# - BigTable (also called Column-Oriented)
# - Graph style: Conjuntos de datos asociativos.
#
# Cabe resaltar que existe solapamiento entre este tipo de definiciones, por lo que en ocasiones, la definición o categorización no resulta clara.

# %% [markdown]
# ##**Qué une a las bases de datos NoSQL:**
#
# La característica principal de las bases de datos NoSQL, como hemos mencionado, es que son bases de datos no relacionales (filas y columnas, por ejemplo). A parte, tenemos las siguientes características comunes:
#
# - Gran parte de estas bases de datos son *open source*, lo que ha impulsado el crecimiento de la industria. A menudo se puede observar algunas empresas que ofrecen una versión comercial de bases de datos y soporte de dicha tecnología, y, al mismo tiempo, están patrocinadas por la contraparte open-source. Algunos ejemplos son
#   - Datastax para Apache Cassandra
#   - IBM Cloudant para CouchDB
#   - Mongo que tienen su propia versión open source de bases de datos.
#
# - La mayoría de bases de datos NoSQL son construidas escalar horizonalmente y compartir sus datos de forma más sencilla que las contrapartes relacionales. Para realizar esto, a menudo se requieren de *keys* únicas para bases de datos completas.
#
# - Las bases de datos NoSQL son más especializadas que las RDBMS.
#
# - Las DB NoSQL permiten un desarrollo más ágil por medio de esquemas más flexibles que los esquémas fijos de las bases de datos relacionales.

# %% [markdown]
# ## **¿Por qué deberíamos usar DBs NoSQL y a qué se debe su popularidad?**
#
# Alguna de las razones más comunes son:
#
# - Escalabilidad: habilidad para escalar horizontalmente a lo largo de diferentes clusters o servidores, racks, y posiblemente con centros de datos. En este sentido, resulta clave que las DBs NoSQL tienen una elasticidad para escalar tanto hacia arriba, como hacia abajo, las demandas variables de las aplicaciones. Las DBs NoSQL son adecuadas para satisfacer los grandes tamaños de datos y la gran cantidad de usuarios que concurren en realación con las aplicaciones que exhiben un comportamiento de Big Data.
#
# - Rendimiento: Relacionado on la escalabilidad, tenemos el rendimiento. En las grandes bases de datos es indispensable entregar respuestas rápidas en el tiempo.
# - Disponibilidad, el cual es un requerimiento obvio para las DB, ya qe deben correr en un cluster de servidores, con multiples copias de los datos para tener una solución resiliente que la disponibilidad en un solo servidor.
# - Compatibilidad con arquitectura en la nube: Muchas empresas actuales emplean arquitecturas en la nube para el soporte de aplicaciones. Históricamente, las bases de datos grandes han corrido en máquinas u ordenadores centrales costoso. La naturaleza distribuida de las bases de datos NoSQL significa que estas pueden desplegarse y operarse en clusters de servidores en arquitecturas en la nube.
# - Costo
# - Flexibilidad de esquemas: lo que significa que podemos construir nuevas funciones dentro de la apicación de forma rápida sin que las bases de datos se bloquen o tengan tiempos de inactividad.
# - Estructuras intuitivas: Las bases de datos NoSQL tiene varias estructuras que permiten abordar diferentes necesidades de desarrollo que la RDBMS.
# - Capacidades especializadas: algunas de estas son
#   - Capacidades específicas de indexación geospaciales o de busqueda.
#   - Robustez en la replicación de datos.
#   - APIs HTTP modernas.

# %% [markdown]
# #**Definición de tipos de bases de datos NoSQL, opciones y casos de uso**
#
# **Objetivos de la sección**
#
# - Definición de los tipos más importantes de bases de datos NoSQL.
# - Descripción de los usos principales en cada caso.
# - Distinción de las mayores diferencias de arquitectura entre los tipos.
# - Ventajas y desventajas de cada tipo.

# %% [markdown]
# ##**Modelos de datos NoSQL**
#
# Existen cuatro tipos de bases de datos NoSQL:
#
# - Key-Value
# - Document
# - Column-family
# - Graph
#
# De forma gráfica, en la siguiente figura se ilustra el porcentaje de uso de cada tipo de bases de datos NoSQL
#
# ![image.png](data:image/png;base64,...)
#
# Analicemos cada uno de los tipos en términos de **arquitectura** y **casos de uso**.

# %% [markdown]
# ###**Key-Value**

# %% [markdown]
# ####**Arquitectura**
#
# Las bases de datos **Key-Value** son las menos complejas de todas de los tipos de bases de datos NoSQL. Todos los datos se almacenan con una clave (key) y un blob de valor asociado.
#
# **Pros:**
#
# Debido a que el almacenamiento de forma Key-Value representa un hashmap (array a cuyos elementos se puede acceder mediante un número o un string), son potentes para realizar operaciones básicas de CRUD (Create-Read-Update-Delete), y, generalmente, se escalan bastante bien y se fragmentan fácilmente en un número $x$ de nodos.
#
# **Contras:**
#
# Cada **fragmento** contendrá un rango dado de claves y valores asociados. Sin embargo, estas bases de datos no se usan para consultas complejas que intentan conectar varias piezas de datos, y son atómicos solo para una sola clave. El valor blob es opaco y, por lo tanto, generalmente tendrá menos flexibilidad cuando se trata de indexar y consultar los datos que otros tipos de bases de datos.
#
# **Resumen**:
#
# - Almacenamiento de datos basados en una clave única en un **hashmap**.
# - El Valor "blob" asociado con una clave es "opaco" para la base de datos.
# - Alto rendimiento en operaciones básicas CRUD, pero rendimiento deficiente en consultas complejas o datos interconectados.
# - Característica atómica solo para operaciones de una clave única.
# - Escalable horizontalmente a través del fragmentado.

# %% [markdown]
# ####**Casos de uso**
#
# Cada véz que se necesitemos un buen rendimento para operaciones básicas CRUD y los datos no estén interconectados, la mejor opción de base de datos NoSQL son las de tipo Key-Value.
#
# Ejemplo:
#
# - Almacenamiento y recuperación de información de una aplicación web: Cada sesión de usuario recibirá algún tipo de valor único tipo key y todos los datos serán almacenados juntos en un valor *blob* opaco. Además, no habría necesidad de consultar en función de la información en el blobl de valores. Todas las transacciones se basarían en el key único.
# - Un uso similar se prodría presentar en el caso del almacenamiento de perfiles y preferencias de usuarios dentro de una aplicación.
# - Almacenamiento de datos en un carrito de compra en línea en las tiendas o mercados.
#
# En estos ejemplos, las consultas o manipulaciones de realaciones complejas entre diferentes claves serían muy pocas y distantes entre sí. Cualquier caso que se aleje de este escenario es inadecuado para la implementación de bases de datos NoSQL basadas en claves.
#
# Los casos ene los que no se debe usar bases de datos NoSQL se resumen a continuación:
#
# - Relaciónes entre los datos de muchos contra muchos,
# - Requerimiento de una consistencia de alto nivel para transacciones de múltiples operaciones.
# - Si pretende realizar una consulta del valor vs la clave.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Document DB**

# %% [markdown]
# #### **Arquitectura**
#
# Las bases bases de datos **Document** se basan en el modelo *key-value* al hacer que el valor sea visible y pueda consultarse.
#
# Cada dato se considera un documento y almacenado como alguno de los siguientes archivos:
#
# - JSON
# - XML
# - BSON
#
# Una de las ventajas de las bases de datos de **documentos** es que cada **documento** ofrece un esquema flexible, en el que no es necesario que dos documentos sean iguales o contengan la misma información. Las bases de datos de documentos generalmente ofrecen la capacidad de indexar y consultar el contenido de los documentos, ofreciendo búsquedas de rango de valores y claves y capacidad de búsqueda, o quizás consultas analíticas a través de paradigmas como MapReduce.
#
# Las bases de datos de **documentos** son escalables horizontalmente y permiten la fragmentación a través de múltiples nodos, típicamente fragmentados por alguna clave única en el documento. Generalmente, el almacenamiento de documentos solo garantizan transacciones atómicas en operaciones de un solo documento.
#
# **Resumen Document DB**
#
# - Los datos son guardados como documentos: JSON, XML, BSON, etc.
# - Los documento son autodescriptivos y los datos tienen una jerarquía de árbol.
# - Son similares a las bases de datos Key-Value pero el <font color='red'>valor es visible y examinable</font>.
# - Uso de MapReduce para indexado y analítica.
# - Esquemas de entrada flexibles ("schema-less")
# - Atomicos solo para operaciones de un solo docimento.
# - Escalables horisontalmente a través de particiones.

# %% [markdown]
# #### **Casos de uso:**
#
# Algunos casos de usos de bases de datos NoSQL  de tipo **Document** son:
#
# - **Registro de eventos**, para una aplicación o proceso: Cada instancia puede constituir un nuevo documento o agregado que contiene toda la información del evento correspondiente.
# - **Blogs online y otras aplicaciones web:** Cada usuario se representaría por un documento; cada post como documento; cada comentarior, like, o acción sería un documento.
# - **Datos operacionales y metadatos para aplicaciones web/movil**
#
# Todos los documentos contendrían información relacionada con el tipo de datos, como nombre de usuario, contenido de publicación o timestamp de cuándo se creó el documento. En términos más generales, el almacenamiento de documentos funciona bien con conjuntos de datos operacionales para aplicaciones web y móviles. Estas bases de datos fueron diseñados teniendo en cuenta el internet, pensando en documentos JSON, API RESTful y datos no estructurados.

# %% [markdown]
# #### **Caso en los que falla**
#
# Otros modelos de bases de datos pueden ser mejores soluciones cuando se necesitan transacciones ACID. No es posible en el almacenamiento de un documento manejar una transacción que opera en varios documentos y una base de datos relacional puede ser una mejor opción.
#
# En segundo lugar, las bases de datos de cocumentos pueden resultar en una opción incorrexta si se encuentra forzando los datos en un diseño <font color='red'>aggregate-oriented</font>. Si pertenece de forma natural a un modelo normalizado/taular, esto implica la investigación de bases de datos relacionales.
#
# Las bases de datos de documentos son, actualmente, las nases de datos NoSQL más polulares. Algunas de estas bases de datos se muestran a continuación.
#
#
# ![texto alternativo](https://github.com/ssanchezgoe/diplomado_udea/blob/master/NoSQL_DB/document_DB.png?raw=true)

# %% [markdown]
# ### **Column-Family databases**

# %% [markdown]
# ####**Arquitectura**
#
# Las bases de datos **Column-Family** surgieron de una arquitectura que google creó llamada **BigTable**. Por lo tanto, estas bases de datos también se conocen cómo clones de BigTable o **Columnar databases**.
#
# Como se deduce del nombre, estas bases de datos se centran en columnas y grupos de columnas cuando se almacena y se accede a los datos.
#
# Las bases de datos **Column-Family** estan conformadas por diversas filas, cada una con una clave o identificador único, que pertenecen a una o más columnas. Estas columnas se agrupan en familias

# %% [markdown]
# ##**MongoDB**
#
# MongoDB es una base de datos basada en documentos JSON, con gran escalabilidad y flexibilidad que se desee respecto a las búsquedas e indexaciones deseadas.
#
# MongoDB es muy fácil de instalar e implementar. Por otra parte, proporciona un gran rendimiento, amplia disponibilidad y escalado automático.

# %% [markdown]
# #**MongoDB**
#
# En esta sección se abordarán los siguientes temas:
#
# - Definición de MongoDB
# - Definición de docmentos `BSON`
# - Configuración de una cuentra gratuita en [*MongoDB Atlas*](https://www.mongodb.com/cloud/atlas/lp/try2?utm_source=google&utm_campaign=gs_americas_colombia_search_brand_atlas_desktop&utm_term=mongodb%20atlas&utm_medium=cpc_paid_search&utm_ad=e&utm_ad_campaign_id=2030069987&gclid=EAIaIQobChMIuq_HocPX6wIVBjiGCh3TXQl3EAAYASAAEgKbr_D_BwE)

# %% [markdown]
# ##**Definición `MongoDB`:**
#
# `MongoDB` es un sistema de base de datos NoSQL, orientado a documentos y de código abierto.
#
# El tipo de documentos que guarda se conoce como `BSON`.
#
# `MongoDB` es una base de datos facilmente escalable, pa use de producción y con funcionalidades múltiples

# %% [markdown]
# ##**Archivos `BSON`**
#
# Un objeto BSON es un formato usado para el intercambio de datos y almacenamiento en la base de datos `MongoDB`. Es una representación binaria de estructuras de datos y mapas, de ahí su nombre BSON que significa *Binary JSON*.
#
# Un objeto *BSON* es una lista ordenada de elementos de diferentes tipos como:
#
# - `string`
# - `int64/32`
# - Datos reales de 64 bits
# - `Date`
# - `array` de bytes
# - `bool`
# - `Null`
# - Objeto BSON
# - Arreglo BSON
# - Expresiones regulares
# - Código JavaScript
#
# Los tipos soportados por un objeto `BSON` son los mismos que el caso de un objeto `JSON`, añadiendse los tipos `Date` y arreglos de bytes.

# %% [markdown]
# #**MongoDB Atlas**
#
# MongoDB Atlas es un producto proporcionado por MongoDB, que corresponde a una plataforma en la nube, que nos proporciona Mongodb como un servicio.
#
# De esta forma, no tenemos que instalar y configurar MongoDB en nuestras máquinas locales.
#
# Podemos usar directamente el cluster de mongoDB, que estará alojado en la nube por [**MongoDB Atlas**](https://www.mongodb.com/cloud/atlas). Lo mejor de todo es que podemos usarlo de forma gratuita.

# %% [markdown]
# #**`Pymongo`**
#
# En esta sección se abodatán los siguientes temas:
#
# - Introducción: Definición de `PyMongo`.
# - Conexión a
# - Operaciones CRUD en single documents.
# - Operaciones CRUD en Embedding documents.

# %% [markdown]
# **Instalación de dnspython**

# %% [markdown]
# ##**Introducción**
#
# `PyMongo` es una distribución de `Python` que contienen herramientas para trabajar con `MongoDB`, y es la forma que recomiendan los creadores de MongoDB para trabajar con dicha base de datos (ver los siguientes links: [link1](https://pymongo.readthedocs.io/en/stable/) y [link2](https://api.mongodb.com/python/current/tools.html#:~:text=It%20retains%20pymongo's%20query%20and,The%20source%20is%20on%20GitHub.&text=Manga%20aims%20to%20be%20a,layer%20on%20top%20of%20PyMongo.))
#
# Podemos trabajar de dos forma mongoDB con pymongo:
#
# - De forma local, es decir en nuestro pc, instalando `MongoDB`.
#
# - De forma remota, que será la usada en este diplomado, en donde configuraremos una cuenta gratuita en [*MongoDB Atlas*](https://www.mongodb.com/cloud/atlas/lp/try2?utm_source=google&utm_campaign=gs_americas_colombia_search_brand_atlas_desktop&utm_term=mongodb%20atlas&utm_medium=cpc_paid_search&utm_ad=e&utm_ad_campaign_id=2030069987&gclid=EAIaIQobChMIuq_HocPX6wIVBjiGCh3TXQl3EAAYASAAEgKbr_D_BwE)

# %% [markdown]
# ##**Conexión a una base de datos en MongoDB Atlas y obtención de información de una colección**
#
# Para conectactnos a una base de datos en MongoDB Atlas, debemos instanciar antes un cliente Mongo en `pymongo` mediante el constructor `MongoClient`.
#
# En el siguiente ejemplo visualizaremos una base de datos existente en la cuenta que creamos de **MongoDB Atlas**
#
# **Paso previo:** Instalación de dnspython:

# %%
# !pip install dnspython
# Out:
# ...
#      |████████████████████████████████| 215kB 2.8MB/s
# ...

# %%
# Información db

# %% [markdown]
# ##**Single Documents**

# %% [markdown]
# ##**Creación de una colección**

# %% [markdown]
# Para crear nuestra base de datos nueva, podemos acceder a una base de datos que definamos por defecto, y mediante la el cliente de conexión, crear la base de datos con un nombre nuevo:

# %%
# Creación db

# %% [markdown]
# ## **Insert: Inserción de documentos**

# %% [markdown]
# ###**Inserción de un documento en una base de datos**
#
# Para insertar un documento, creamos un "cursor" a la base de datos en MongoDB Atlas. Mediante el método `insert_one()`, posicionados en la colección en la que deseamos insertar el documento:

# %%
from pymongo import MongoClient

def insert_one(doc = {'Nombre':'Sebastian',
                    'Apellido':'Ramirez',
                    'Edad':36,
                    'Profesion':'Química Farmaceutica',
                    'Sexo':'M'}, 
                    clave = "test", 
                    db_name = "test", 
                    coll_name = "estudiantes"):
  
    url_db = "mongodb+srv://ssanchez2:{}@cluster0.a463h.mongodb.net/{}?retryWrites=true&w=majority".format(clave, db_name)         

    # Conexion
    cliente = MongoClient(url_db)

    #SELECCIÓN DB 2 FORMAS
    #db = cliente.get_database(db_name)
    db = cliente[db_name]
    
    db[coll_name].insert_one(doc)

    print("Inserción satisfactoria del documento: %s" % doc)
 
    cliente.close()

if __name__ == '__main__':
    insert_one()
# Out:
# Inserción satisfactoria del documento: {'Nombre': 'Sebastian', 'Apellido': 'Ramirez', 'Edad': 36, 'Profesion': 'Química Farmaceutica', 'Sexo': 'M', '_id': ObjectId('5f58e239307d945fc526ab47')}

# %% [markdown]
# Consultemos ahora cuantas colecciones hay en nuestra base de datos y cuantos documentos en la colección creada:

# %%
db_info(clave = "test", db_name = "test", coll_name = "estudiantes")
# Out:
# Número de colecciones en test es: 1
# Número de documentos en estudiantes es: 1

# %% [markdown]
# Vemos entonces que hemos insertardo correctamente un documento. Si consultamos en el tablon online de MongoDB Atlas, podremos ver el elemento creado.
#
# **Nota:** En caso de no observar el elemento, refresca la base de datos en la pestaña superior derecha, dentro de las el conjunto de colecciones.

# %% [markdown]
# ###**Inserción de varios documentos:**

# %%
from pymongo import MongoClient

def ins_many_docs(new_docs, clave = 'test', db_name = 'test', coll_name = 'estudianes'):
    
    #Conexión
    cliente = MongoClient("mongodb+srv://ssanchez2:{}@cluster0.a463h.mongodb.net/{}?retryWrites=true&w=majority".format(clave, db_name))
    
    # Selección de la base de datos
    db = cliente.get_database(db_name)

    # Inserción de varios documentos
    db.estudiantes.insert_many(new_docs)

    # Cierre de conexión
    cliente.close()

if __name__ == "__main__":
  new_docs = [{'Nombre':'Catalina',
                 'Apellido':'Henandez',
                 'Edad':25,
                 'Profesion':'Ingenieria Ambietal',
                 'Sexo':'F'
                 },
                {'Nombre':'Jorge',
                 'Apellido':'Alzate',
                 'Edad':32,
                 'Profesion':'Negocios Internacionales',
                 'Sexo':'M'
                 },
                {'Nombre':'Clara',
                 'Apellido':'Idarraga',
                 'Edad':41,
                 'Profesion':'Ingenieria Electrónica',
                 'Sexo':'M'
                } ,
                {'Nombre':'Fernando',
                 'Apellido':'Cuellar',
                 'Edad':28,
                 'Profesion':'Economia',
                 'Sexo':'M'
                },
                {'Nombre':'Camila',
                 'Apellido':'Cifuentes',
                 'Edad':28,
                 'Profesion':'Ingenieria de Procesos',
                 'Sexo':'M'
                }
              ]
                
  ins_many_docs(new_docs)

# %% [markdown]
# Corroboremos que se hayan insertado correctamente los documentos:

# %%
db_info(clave='test', db_name = 'test', coll_name = 'estudiantes')
# Out:
# Número de colecciones en test es: 1
# Número de documentos en estudiantes es: 4

# %% [markdown]
# ##**Select**:

# %% [markdown]
# ###**Selección simple haciendo un match:**

# %%
from pymongo import MongoClient
from tabulate import tabulate

def select_sex(clave = 'test', db_name = 'test', coll_name = 'estudiantes', Sexo = 'F'):
    #Establecemos conexión con la base de datos
    cliente = MongoClient("mongodb+srv://ssanchez2:{}@cluster0.a463h.mongodb.net/{}?retryWrites=true&w=majority".format(clave, db_name))
    
    # Escogemos base de datos 
    db = cliente[db_name]

    #Buscar todos
    est_doc = db[coll_name].find({'Sexo': Sexo})

    #Cuentas de entradas en la colección
    est_counts = db[coll_name].find({'Sexo': Sexo}).count()

    if not est_doc:
        print("No se encontró un estudiantes con esas características" )
    else:
        # Si solo busco uno, o hay uno, descomentar líneas.
        #print(est_doc)
        print("Existen %d documentos en la colección" % est_counts)
        print(tabulate(est_doc, headers = "keys"))
        

    cliente.close() 

if __name__ == "__main__":
    select_sex()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   from ipykernel import kernelapp as app
# Existen 1 documentos en la colección
# _id                       Nombre    Apellido      Edad  Profesion            Sexo
# ------------------------  --------  ----------  ------  -------------------  ------
# 5f584e8852c8652c82370aad  Marcela   Angarita        40  Ingenieria Mecanica  F

# %% [markdown]
# ###**Selección compuesta:**
#
# Veamos algunas recuperaciones de datos con instrucciónes de búsqueda compuesta que se pueden realizar mediante `pymongo`:

# %%
from pymongo import MongoClient
from pymongo import DESCENDING, ASCENDING

def compose_selection(clave = 'test', db_name = 'test', coll_name ='estudiantes', sel = 'A'):
    # Conexión
    url_db = "mongodb+srv://ssanchez2:{}@cluster0.a463h.mongodb.net/{}?retryWrites=true&w=majority".format(clave, db_name)
    cliente = MongoClient(url_db)
    
    # Obtención del database
    db = cliente[db_name]

    stmt_find = {"Sexo":"M"}
    stmt_sort = "Edad"

    if sel == 'A':
      estudiantes = db[coll_name].find(stmt_find).sort(stmt_sort, DESCENDING)
    
    if sel == 'B':
      estudiantes = db[coll_name].find(stmt_find, sort=[(stmt_sort, DESCENDING)])

    if sel == 'C':
      # Limitando cantidad de resultados: 0 -> sin límites
      estudiantes = db[coll_name].find().sort("Edad", DESCENDING).limit(0)
    
    if sel == 'D':
      # Haciendo skipping, Mostrar con 0 y con 2
      estudiantes = db[coll_name].find().sort("Edad", ASCENDING).limit(2).skip(2)

    # Visualización
    for estudiante in estudiantes:
        print(estudiante.get("Nombre"), estudiante.get("Edad"), estudiante.get("Profesion"))
    
    cliente.close()


if __name__ == "__main__":
    compose_selection(sel = 'D')
# Out:
# Camila 28 Ingenieria de Procesos
# Ramon 29 Administracion de Empresas

# %% [markdown]
# ##**Update: Actualización de datos**
#
# Vamos algunas operaciones de actualización de datos.

# %%
# update

# %% [markdown]
# ##**Delete: Actualización de datos**
#
# Veamos algunas formas de hacer para la eliminación de datos. Agregemos unos datos que eliminaremos:

# %%
new_docs = [{'Nombre':'Mario',
                 'Apellido':'Pacheco',
                 'Edad':25,
                 'Profesion':'Ingenieria Ambietal',
                 'Sexo':'F'
                 },
                {'Nombre':'Mario',
                 'Apellido':'Trujillo',
                 'Edad':32,
                 'Profesion':'Negocios Internacionales',
                 'Sexo':'M'
                 },
                {'Nombre':'Clara',
                 'Apellido':'Lopez',
                 'Edad':41,
                 'Profesion':'Ingenieria Electrónica',
                 'Sexo':'M'
                } ,
                {'Nombre':'Edgar',
                 'Apellido':'Cuellar',
                 'Edad':80,
                 'Profesion':'Economia',
                 'Sexo':'M'
                },
                {'Nombre':'Carmen',
                 'Apellido':'Chacon',
                 'Edad':80,
                 'Profesion':'Ingenieria de Procesos',
                 'Sexo':'M'
                }
              ]

ins_many_docs(new_docs)

# %% [markdown]
# Procedamos a la realización de algunas operaciones de eliminación de datos

# %%
from pymongo import MongoClient

def delete(clave = 'test', db_name = "test", coll_name = "estudiantes", sel = 'A'):
    
    url_db = "mongodb+srv://ssanchez2:{}@cluster0.a463h.mongodb.net/{}?retryWrites=true&w=majority".format(clave, db_name)

    # Conexión
    cliente = MongoClient(url_db)

    # SELECCION de la base de datos (2 formas)
    db = cliente[db_name]
    #db = cliente.get_database(db_name)

    # db INFO before delete
    db_info()

    # Eliminación de un registro
    if sel == 'A':
      db[coll_name].delete_one({'Nombre':'Mario', 'Apellido':'Pacheco'})
    if sel == 'B':
      # DELETE WITH $or
      db[coll_name].delete_many({'Nombre':'Sebastian', "$or":[{'Edad':35},{'Edad':36}]})

    print(len("Número de colecciones en test es: i")*"-")

    # db INFO after delete
    db_info()

if __name__ == "__main__":
    delete(sel = 'B')
# Out:
# Número de colecciones en test es: 1
# Número de documentos en estudiantes es: 14
# -----------------------------------
# Número de colecciones en test es: 1
# Número de documentos en estudiantes es: 12

# %% [markdown]
# ##**Emdedding Documents**

# %% [markdown]
# #**Google Firebase**
#
# Google firebase es una base de datos NoSQL, en la nube, que hace uso de modelos de documentos de datos tipo JSON y se sincronizan en tiempo real con cada cliente que está conectado.
#
# Firebase incluye dos formas de almacenamiento de datos:
#
# - Real-Time Database
# - Cloud Firestore
#
# Las diferencias principales las podemos encontrar en el siguiente [link](https://firebase.google.com/docs/firestore/rtdb-vs-firestore)
#
# A lo largo de la presente sección estaremos usando el sdk oficial de python para firebase `firebase_admin` (ver [link](https://firebase.google.com/docs/reference/admin/python?hl=es))

# %% [markdown]
# **Enlaces de interés**
#
# 1. [Iniciación en Cloud Firestore](https://firebase.google.com/docs/firestore/quickstart?hl=es)
# 2. [SDK firebase y bibliotecas cliente](https://firebase.google.com/docs/firestore/client/libraries?hl=es)
# 3. [Firebase Admin Python SDK](https://firebase.google.com/docs/reference/admin/python?hl=es)
# 4. [Cloud Firestore o Realtime Database](https://firebase.google.com/docs/firestore/rtdb-vs-firestore)

# %%
# !pip install firebase-admin

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/My\ Drive/firebase
# Out:
# /content/drive/My Drive/firebase

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

# %% [markdown]
# ##**Realtime Database**

# %% [markdown]
# ###**Conexión a la base de datos firebase real-time**

# %%
# Credenciales
cred = credentials.Certificate('pythondb2-firebase-adminsdk-9mhwr-5fbb39722b.json')

#Inicializar app
firebase_admin.initialize_app(cred,{'databaseURL':'https://pythondb2.firebaseio.com/'})

# %% [markdown]
# ###**Insert**
#
# Una vez creada la base de datos, podemos insertar registros de dos formas, al crear un objeto referencia `db.reference`
#
# - set(), sin key
# - push(), con key
#
# La referencia representa un nodo en la base de datos, los cuales pueden ser asociados a **Colecciones** y **Documentos**.
#
# Vemos las dos formas de realizar una inserción de datos en **firebase**.

# %%
#Con set  

referencia = db.reference('/')

# Método 1: set
referencia_empleados = referencia.set({
    'EmpleadosA':{
        'Empleado1':{
            'nombre':'Arturo',
            'apellido': 'Alvarez',
            'edad':31
        },
        'Empleado2':{
            'nombre':'Catalina',
            'apellido':'Sierra',
            'edad':26
        }
    }
})

# %%
print('key: ', referencia.key)
# Out:
# key:  None

# %% [markdown]
# Para generarlo con una clave una clave, hacemos el mísmo procedimiento anterior, pero usando el método `push()`

# %%
# Con push
referencia = db.reference('EmpleadosB')

referencia_empleados = referencia.push({
            'Empleado1':{
            'nombre':'Camilo',
            'apellido': 'Fernandez',
            'edad':22
                },
            'Empleado2':{
            'nombre':'Saul',
            'apellido':'Restrepo',
            'edad':34
            }
    })

# %%
print('Key eEmpleadosB: %s' %referencia.key)
print('Key empleados: %s' %referencia_empleados.key)
# Out:
# Key eEmpleadosB: EmpleadosB
# Key empleados: -MGj6NkzxO_RMuDVV_wB

# %% [markdown]
# ###**Retrieve: Recuperación de datos**

# %% [markdown]
# Supongamos que queremos recuperar de la tabla los datos de de `EmpleadosA`. Para eso, creamos una referencia a `EmpleadosA` y mediante el método `get()`, obtenemos

# %%
referencia = db.reference('EmpleadosA')
print(referencia.get())
# Out:
# {'Empleado1': {'apellido': 'Alvarez', 'edad': 31, 'nombre': 'Arturo'}, 'Empleado2': {'apellido': 'Sierra', 'edad': 26, 'nombre': 'Catalina'}}

# %%
referencia = db.reference('EmpleadosB')
print(referencia.get())
# Out:
# {'-MGj6NkzxO_RMuDVV_wB': {'Empleado1': {'apellido': 'Fernandez', 'edad': 22, 'nombre': 'Camilo'}, 'Empleado2': {'apellido': 'Restrepo', 'edad': 34, 'nombre': 'Saul'}}}

# %% [markdown]
# ###**UPDATE: Actualización de datos**

# %% [markdown]
# ####**Single Update:**
#
# Lo primero que debemos hacer es crear una referencia "padre"  a `Empleados` y, dentro de esta, una referencia hija a `Empleados1`:

# %%
#Creación de referencias
ref = db.reference('EmpleadosA')

# Dentro de la referencia padre, podemos hacer 
ref_empleado = ref.child('Empleado1')

ref_empleado.update({'Nombre':'Adrian'})

# %% [markdown]
# ####**Multiple update**
#
# Para hacer una actualización multiple, solo hacemos una referencia al padre `Empleados`, y desde la referencia invocamos el método `update()`:

# %%
ref = db.reference('EmpleadosA')
ref.update({
    'Empleado1/apellido':'Arteaga',
    'Empleado2/apellido':'Cañas',
})

# %% [markdown]
# ###**DELETE: Eliminación de datos**
#
# Agregemos antes una colección nueva que luego eliminaremos por partes:
#
# 1. Un documento primero.
# 2. La colección completa.

# %%
referencia = db.reference('EmpleadosC')

referencia_empleados = referencia.push({
            'Empleado1':{
            'nombre':'Camilo',
            'apellido': 'Fernandez',
            'edad':22
                },
            'Empleado2':{
            'nombre':'Saul',
            'apellido':'Restrepo',
            'edad':34
            }
    })

# %% [markdown]
# Podemos borrar un documento de la colección de la forma:

# %%
ref_emp1 = referencia_empleados.child('Empleado1')
ref_emp1.delete()

# %% [markdown]
# O la "colección" entera como:

# %%
referencia.delete()

# %% [markdown]
# **Cerramos la app después de hacer todo:**
#
# Una vez hayamos terminado todos los procesos que queremos realizar en la base de datos de `real-time`, nos encargamos de cerrar la app.

# %%
firebase_admin.delete_app(firebase_admin.get_app())

# %% [markdown]
# ##**Cloud Firestore**
#
# Una guía general rápida (quickstart) la podemos encontrar en el [este link](https://firebase.google.com/docs/firestore/quickstart?hl=es).

# %% [markdown]
# ###**Conexión a la base de datos firestore**

# %%
cd firestore/
# Out:
# /content/drive/My Drive/firebase/firestore

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %%
# Credenciales
cred = credentials.Certificate('pythondb2-firebase-adminsdk-9mhwr-5fbb39722b.json')

#Inicializar app
firebase_admin.initialize_app(cred)

db = firestore.client()

# %% [markdown]
# ###**Creación de una colección e inserción de un elemento**
#
# Para la creación de una **colección** e inserción de un elemento, escribimos la siguiente sentencia:

# %%
doc_ref = db.collection('Empleados').document('EmpleadosA')

doc_ref.set({'nombre':'Arturo',
              'APELLIDO': 'Alvarez',
              'EDAD':31,
              'SALARIO' : 3000000,
              'SEXO' : 'M'
             })
# Out:
# update_time {
#   seconds: 1599601772
#   nanos: 301574000
# }

# %% [markdown]
# En caso de no incluir la operación de inserción `set()`, la tabla no será creada en *Cloud Firestore*. Notese que a set le hemos pasado un `ID` del documento que es `EmpleadosA`.
#
# Si deseamos que sea `Firebase` el que asigne automáticamente un 'ID', usamos el método `add()`:

# %%
empleado = {'NOMBRE':'Carlos', 'APELLIDO': 'Valencia', 'EDAD':45, 'SALARIO':3500000, 'SEXO':'M'}
db.collection('Empleados').add(empleado)
# Out:
# (seconds: 1599601815
#  nanos: 547780000,
#  <google.cloud.firestore_v1.document.DocumentReference at 0x7f71a2a317f0>)

# %% [markdown]
# ###**INSERT**
#
# En *Firestore* solo tenemos un método para insertar documentos en una colección. Si queremos insertar varios documentos, podemos hacerlo mediante la creación de un objeto `batch()`, o lotes, sin embargo, el este concepto de lotes, puede aplicarse a varias operaciones concatenadas como
#
# 1. Inserción de dato.
# 2. Actualización.
# 3. Eliminación.
#
# Luego de finalizar la secuencia, debemos invocar el método `commit()` del objeto `batch()`.
#
# A continuación realizaremos la inserción de varios documentos a la colección.

# %%
#Definición del batch
batch = db.batch()

# Preparación de los datos
docID = ['B','C','D','E','F','G','H','I']
registros = [{'NOMBRE':'Ana', 'APELLIDO': 'Correa', 'EDAD':33, 'SALARIO':4700000, 'SEXO':'F'},
             {'NOMBRE':'Maria', 'APELLIDO': 'Garcia', 'EDAD':43, 'SALARIO':5600000,'SEXO':'F'},
             {'NOMBRE':'Amadeo', 'APELLIDO': 'Perez', 'EDAD':22, 'SALARIO':6900000, 'SEXO':'M'},
             {'NOMBRE':'Pablo', 'APELLIDO': 'Molina', 'EDAD':34, 'SALARIO':2200000, 'SEXO':'M'},
             {'NOMBRE':'Carmen', 'APELLIDO': 'Chacon', 'EDAD':38, 'SALARIO':7300000, 'SEXO':'F'},
             {'NOMBRE':'Oscar', 'APELLIDO': 'Prieto', 'EDAD':44, 'SALARIO':3400000, 'SEXO':'M'},
             {'NOMBRE':'Ana', 'APELLIDO': 'Quiroga', 'EDAD':25, 'SALARIO':1800000, 'SEXO':'F'},
             {'NOMBRE':'Felipe', 'APELLIDO': 'Estrada', 'EDAD':29, 'SALARIO':3250000, 'SEXO':'M'}
             ]
for i in range(0,len(docID)):
  referencia = db.collection('Empleados').document('Empleado'+docID[i])
  batch.set(referencia, registros[i])

batch.commit()
# Out:
# [update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }, update_time {
#    seconds: 1599602151
#    nanos: 763670000
#  }]

# %% [markdown]
# Esta inserción por lotes, la pudimos haber realizado una por una, con un `for`.

# %% [markdown]
# ###**Recuperación de datos "like SQL"**
#
# En la presente sección estudiaremos
#
# - Lectura de datos general.
# - Recuperación de datos simples y compuestas ([ver referencia](https://firebase.google.com/docs/firestore/query-data/queries))
# - Ordenación y limitación de búsquedas ([ver referencia](https://firebase.google.com/docs/firestore/query-data/order-limit-data?hl=es))

# %% [markdown]
# ####**Recuperación de datos en general.**
#
# Para recuperar todas las entradas de nuestra tabla, la cual es pequeña de momento, accedemos a la colección y ahí, creamos una referencia:

# %%
ref_empleados = db.collection('Empleados')

# %% [markdown]
# La referencia posee un método `stream()` el cual lee todos los documentos en la colección y retorna un iterador que consume cada documento retornado en el stream:

# %%
docs = ref_empleados.stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoB => {'SALARIO': 4700000, 'NOMBRE': 'Ana', 'APELLIDO': 'Correa', 'SEXO': 'F', 'EDAD': 33}
# EmpleadoC => {'EDAD': 43, 'NOMBRE': 'Maria', 'SALARIO': 5600000, 'APELLIDO': 'Garcia', 'SEXO': 'F'}
# EmpleadoD => {'APELLIDO': 'Perez', 'SEXO': 'M', 'EDAD': 22, 'NOMBRE': 'Amadeo', 'SALARIO': 6900000}
# EmpleadoE => {'EDAD': 34, 'SALARIO': 2200000, 'NOMBRE': 'Pablo', 'APELLIDO': 'Molina', 'SEXO': 'M'}
# EmpleadoF => {'SALARIO': 7300000, 'NOMBRE': 'Carmen', 'APELLIDO': 'Chacon', 'SEXO': 'F', 'EDAD': 38}
# EmpleadoG => {'EDAD': 44, 'SALARIO': 3400000, 'NOMBRE': 'Oscar', 'APELLIDO': 'Prieto', 'SEXO': 'M'}
# EmpleadoH => {'EDAD': 25, 'SALARIO': 1800000, 'NOMBRE': 'Ana', 'APELLIDO': 'Quiroga', 'SEXO': 'F'}
# EmpleadoI => {'APELLIDO': 'Estrada', 'SEXO': 'M', 'EDAD': 29, 'SALARIO': 3250000, 'NOMBRE': 'Felipe'}
# EmpleadosA => {'SEXO': 'M', 'EDAD': 31, 'SALARIO': 3000000, 'nombre': 'Arturo', 'APELLIDO': 'Alvarez'}
# ...

# %% [markdown]
# ####**Recuperaciones Simples:**

# %% [markdown]
# #####**Coincidencia en un campo**

# %% [markdown]
# Con la clausula `where` podemos, por ejemplo, hacer una consulta simple de un registro de los empleados con cierto nombre:

# %%
#recuperación de documentos
docs = db.collection('Empleados').where('NOMBRE','==','Ana').stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoB => {'EDAD': 33, 'SALARIO': 4700000, 'NOMBRE': 'Ana', 'APELLIDO': 'Correa', 'SEXO': 'F'}
# EmpleadoH => {'EDAD': 25, 'NOMBRE': 'Ana', 'SALARIO': 1800000, 'APELLIDO': 'Quiroga', 'SEXO': 'F'}

# %% [markdown]
# Si queremos realizar una consulta más compleja, como extraer un empleado que tiene cierto `NOMBRE` y `APELLIDO`, debemos recurrir a las consultas compuestas, como veremos más adelante.

# %% [markdown]
# #####**Coincidencia en varios campos**
#
# Si se quiere extraer del ejemplo anterior solo la persona con un apellido dato, realizamos dos veces la operación where:

# %%
referencia_empleados = db.collection('Empleados')
docs = referencia_empleados.where('NOMBRE','==','Ana').where('APELLIDO','==','Correa').stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoB => {'APELLIDO': 'Correa', 'SEXO': 'F', 'EDAD': 33, 'SALARIO': 4700000, 'NOMBRE': 'Ana'}

# %% [markdown]
# #####**Organizar por un campo**
#
# Mostremos la lista de empleados organizada por salario

# %%
ref_empleados = db.collection('Empleados')
docs = ref_empleados.order_by('SALARIO').stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoH => {'EDAD': 25, 'SALARIO': 1800000, 'NOMBRE': 'Ana', 'APELLIDO': 'Quiroga', 'SEXO': 'F'}
# EmpleadoE => {'APELLIDO': 'Molina', 'SEXO': 'M', 'EDAD': 34, 'NOMBRE': 'Pablo', 'SALARIO': 2200000}
# EmpleadosA => {'APELLIDO': 'Alvarez', 'SEXO': 'M', 'EDAD': 31, 'SALARIO': 3000000, 'nombre': 'Arturo'}
# EmpleadoI => {'APELLIDO': 'Estrada', 'SEXO': 'M', 'EDAD': 29, 'NOMBRE': 'Felipe', 'SALARIO': 3250000}
# EmpleadoG => {'APELLIDO': 'Prieto', 'SEXO': 'M', 'EDAD': 44, 'SALARIO': 3400000, 'NOMBRE': 'Oscar'}
# b8GbcSMP5HxqOhwXQo26 => {'APELLIDO': 'Valencia', 'SEXO': 'M', 'EDAD': 45, 'NOMBRE': 'Carlos', 'SALARIO': 3500000}
# EmpleadoB => {'EDAD': 33, 'NOMBRE': 'Ana', 'SALARIO': 4700000, 'APELLIDO': 'Correa', 'SEXO': 'F'}
# EmpleadoC => {'APELLIDO': 'Garcia', 'SEXO': 'F', 'EDAD': 43, 'SALARIO': 5600000, 'NOMBRE': 'Maria'}
# EmpleadoD => {'APELLIDO': 'Perez', 'SEXO': 'M', 'EDAD': 22, 'SALARIO': 6900000, 'NOMBRE': 'Amadeo'}
# ...

# %% [markdown]
# Por defecto la lista se encuentra organizada de forma ascendente. Si queremos organizarlos de forma descendente la búsqueda, lo indicamos a través del argumento basado en la clave `direction`

# %%
ref_empleados = db.collection('Empleados')
docs = ref_empleados.order_by('SALARIO', direction = firestore.Query.DESCENDING).stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoF => {'EDAD': 38, 'SALARIO': 7300000, 'NOMBRE': 'Carmen', 'APELLIDO': 'Chacon', 'SEXO': 'F'}
# EmpleadoD => {'EDAD': 22, 'SALARIO': 6900000, 'NOMBRE': 'Amadeo', 'APELLIDO': 'Perez', 'SEXO': 'M'}
# EmpleadoC => {'APELLIDO': 'Garcia', 'SEXO': 'F', 'EDAD': 43, 'SALARIO': 5600000, 'NOMBRE': 'Maria'}
# EmpleadoB => {'APELLIDO': 'Correa', 'SEXO': 'F', 'EDAD': 33, 'SALARIO': 4700000, 'NOMBRE': 'Ana'}
# b8GbcSMP5HxqOhwXQo26 => {'APELLIDO': 'Valencia', 'SEXO': 'M', 'EDAD': 45, 'SALARIO': 3500000, 'NOMBRE': 'Carlos'}
# EmpleadoG => {'APELLIDO': 'Prieto', 'SEXO': 'M', 'EDAD': 44, 'NOMBRE': 'Oscar', 'SALARIO': 3400000}
# EmpleadoI => {'EDAD': 29, 'SALARIO': 3250000, 'NOMBRE': 'Felipe', 'APELLIDO': 'Estrada', 'SEXO': 'M'}
# EmpleadosA => {'EDAD': 31, 'nombre': 'Arturo', 'SALARIO': 3000000, 'APELLIDO': 'Alvarez', 'SEXO': 'M'}
# EmpleadoE => {'EDAD': 34, 'SALARIO': 2200000, 'NOMBRE': 'Pablo', 'APELLIDO': 'Molina', 'SEXO': 'M'}
# ...

# %% [markdown]
# #####**Combinación de filtros `where`, `orderBy` y `limit()`**
#
# Podemos complicar aún más las búsquedas. Por ejemplo, podemos hallar las personas que ganen más de cierto salario, organizarlo por salario y limitar la búsqueda a 3 personas:

# %%
referencia_empleados = db.collection('Empleados')
docs = referencia_empleados.where('SALARIO','>',3000000).order_by('SALARIO').limit(3).stream()

for doc in docs:
  print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# EmpleadoI => {'EDAD': 29, 'NOMBRE': 'Felipe', 'SALARIO': 3250000, 'APELLIDO': 'Estrada', 'SEXO': 'M'}
# EmpleadoG => {'APELLIDO': 'Prieto', 'SEXO': 'M', 'EDAD': 44, 'SALARIO': 3400000, 'NOMBRE': 'Oscar'}
# b8GbcSMP5HxqOhwXQo26 => {'EDAD': 45, 'NOMBRE': 'Carlos', 'SALARIO': 3500000, 'APELLIDO': 'Valencia', 'SEXO': 'M'}

# %% [markdown]
# **Regla importante:**
#
# Si tienes un filtro con una comparación de rangos (`<`, `<=`, `>`o `>=`), el primer ordenamiento que se hace debe ser respecto al mismo campo de la búsqueda, como en el ejemplo anterior.

# %% [markdown]
# ###**UPDATE: Actualización de datos**

# %% [markdown]
# ####**Single Update:**
#
# Lo primero que debemos hacer es crear una referencia "padre"  a `Empleados` y, dentro de esta, una referencia hija a `Empleados1`:

# %%
#Creación de referencias
ref = db.reference('EmpleadosA')

# Dentro de la referencia padre, podemos hacer 
ref_empleado = ref.child('Empleado1')

ref_empleado.update({'Nombre':'Adrian'})

# %% [markdown]
# ####**Multiple update**
#
# Para hacer una actualización multiple, solo hacemos una referencia al padre `Empleados`, y desde la referencia invocamos el método `update()`:

# %%
ref = db.reference('EmpleadosA')
ref.update({
    'Empleado1/apellido':'Arteaga',
    'Empleado2/apellido':'Cañas',
})

# %% [markdown]
# ###**DELETE: Eliminación de datos**
#
# Agregemos antes una colección nueva que luego eliminaremos por partes:
#
# 1. Un documento primero.
# 2. La colección completa.

# %%
referencia = db.reference('EmpleadosC')

referencia_empleados = referencia.push({
            'Empleado1':{
            'nombre':'Camilo',
            'apellido': 'Fernandez',
            'edad':22
                },
            'Empleado2':{
            'nombre':'Saul',
            'apellido':'Restrepo',
            'edad':34
            }
    })

# %% [markdown]
# Podemos borrar un documento de la colección de la forma:

# %%
ref_emp1 = referencia_empleados.child('Empleado1')
ref_emp1.delete()

# %% [markdown]
# O la "colección" entera como:

# %%
referencia.delete()

# %% [markdown]
# **Cerramos la app después de hacer todo:**
#
# Una vez hayamos terminado todos los procesos que queremos realizar en la base de datos de `real-time`, nos encargamos de cerrar la app.

# %%
firebase_admin.delete_app(firebase_admin.get_app())

# %%
pwd
# Out:
# '/content/drive/My Drive/firebase/real_time'
